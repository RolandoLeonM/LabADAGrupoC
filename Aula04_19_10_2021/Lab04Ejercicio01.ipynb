# %% [markdown]
# # Ejercicio 01
#
# Convertir el siguiente algoritmo de O(n^2)
# a un algoritmo secuencial O(n)

# %%
# 1. Convert from 0(n^2) to 0(n)

# Algortimo de O(n^2)

def greatestNumber(array):
# Dado un conjunto de valores la función
# nos retorna el mayor número
    for i in array:
        isIValTheGreatest = True
        for j in array:
            if j > i:
                isIValTheGreatest = False
        if isIValTheGreatest:
            return i

# %%
A=[1,5,7,8,2,15,6]
print(greatestNumber(A))
# Out:
# 15

# %% [markdown]
# **Complejidad computacional**
#
# ![](images/E1_cod1_1.png)
# ![](https://drive.google.com/uc?export=view&id=1G7IHSogKuBc051kniSNAyLrwEQBKw85S)
#
# Entonces la complejidad computacional será $O(n^2)$ es cuadrática

# %% [markdown]
# ## Conversión del algoritmo

# %%
# Algoritmo convertido a O(n)

def mayorNumber(arreglo):
# Dado un conjunto de valores la función
# nos retorna el mayor número
    mayor = arreglo[0]
    # Recorrer y buscar
    for elemento in arreglo:
        if elemento > mayor:
            mayor = elemento
    return mayor

# %%
A=[1,5,7,8,2,15,6]
print(mayorNumber(A))
# Out:
# 15

# %% [markdown]
# **Complejidad computacional**
#
# ![](images/E1_cod1_2.png)
# ![](https://drive.google.com/uc?export=view&id=1lTPpdqfDmKftrj_OO75HcfezFvhxxhrw)
#
# Entonces la complejidad computacional será $O(n)$ es lineal
