# %% [markdown]
# # Ejercicio 1

# %%
def sum_numbers(values):
    """
    Dado un conjunto de numeros
    la función retorna la suma de los mismos
    """
    total = 0
    for n in values:
        total = total + n
    return total

# %%
numbers = [1,2,3,4]
val = sum_numbers(numbers)
print(val)
# Out:
# 10

# %%
numbers = list(range(100))
val = sum_numbers(numbers)
print(val)
# Out:
# 4950

# %% [markdown]
# # Ejercicio 2

# %%
def inverse(values):
    """
    Dado un conjunto de valores la funcion retorna
    un array con los valores en orden inverso
    """
    list_inv = []
    length = len(values)
    for i in range(length -1,-1,-1):
        list_inv.append(values[i])
    return list_inv

# %%
numbers = [1,3,5,7,9]
val = inverse(numbers)
print(val)
# Out:
# [9, 7, 5, 3, 1]

# %% [markdown]
# # Ejercicio 3

# %%
def parImpar(values):
    """
    Dado un conjunto de valores la funcion retorna
    dos array, uno con pares y el otro con impares
    """
    par = []
    impar = []
    for n in values:
        if n % 2 == 0:
            par.append(n)
        else:
            impar.append(n)
    return (par, impar)

# %%
numbers = [1,2,3,4,5,6,7]
val = parImpar(numbers)
pares = val[0]
impares = val[1]
print("Pares:",pares)
print("Impares:",impares)
# Out:
# Pares: [2, 4, 6]
# Impares: [1, 3, 5, 7]

# %% [markdown]
# # Ejercicio 4

# %%
def ordenamientoBurbuja(values):
    """
    Dado un conjunto de valores la funcion ordena
    en forma ascendente, mediante metodo de burbuja
    """
    for n in range(len(values)-1,0,-1):
        for i in range(n):
            if values[i] > values[i+1]:
                temp = values[i]
                values[i] = values[i+1]
                values[i+1] = temp
            
    return values

# %%
numbers = [9,5,8]
val = ordenamientoBurbuja(numbers)
print(val)
# Out:
# [5, 8, 9]

# %% [markdown]
# # Ejercicio 5

# %%
def frameText(text):
    """
    Dado un texto, la funcion imprime el
    texto dentro de un marco de asteriscos
    """
    line = (len(text)+4) * '*'+'\n'
    space = '* ' + (len(text)+1) * ' '+'*\n'
    middle = '* '+ text +' *\n'
    print(line + space + middle + space + line)

# %%
text = "Hello world!"
frameText(text)
# Out:
# ****************
# *              *
# * Hello world! *
# *              *
# ****************

# %% [markdown]
# # Ejercicio 6

# %%
def frameText2(text, num):
    """
    Dado un texto y numero, la funcion imprime el texto dentro
    de un marco de asteriscos determinado por el numero dado
    
    line = (len(text)+4) * '*'+'\n'
    space = '* ' + (len(text)+1) * ' '+'*\n'
    """
    middle = '*' + ' ' * num + text +' ' * num + '*'
    line = '*' * len(middle)
    space = '*' + ' ' * (len(middle)-2)+'*'
    print(line)
    for n in range(num):
        print(space)
    print(middle)
    for n in range(num):
        print(space)
    print(line)

# %%
text = "Hello world!"
num = 3
frameText2(text, num)
# Out:
# ********************
# *                  *
# *                  *
# *                  *
# *   Hello world!   *
# *                  *
# *                  *
# *                  *
# ********************
