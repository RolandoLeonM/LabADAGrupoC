// %% [markdown]
// # Ejercicio 07. ¿Cuál es la complejidad de tiempo?

// %% [markdown]
// ![](images/Q07_img.png)
// ![](https://drive.google.com/uc?export=view&id=1InhzmoUfbSqIBXuomtJtEYPeWH7O7bKN)

// %% [markdown]
// ## Solución:
//
// Hallando la complejidad de tiempo:

// %% [markdown]
// Realizamos el cálculo por deducción o exhaustivo.
//
// |$iteraciones$  |$i$              |potencia  de  2 |
// |---------------|-----------------|----------------|
// |$1$            | $1\rightarrow$  | $2^{0}$        |
// |$2$            | $4\rightarrow$  | $2^{1}$        |
// |$3$            | $8\rightarrow$  | $2^{2}$        |
// |$4$            | $16\rightarrow$ | $2^{3}$        |
// |$5$            | $32\rightarrow$ | $2^{4}$        |
// |$6$            | $64\rightarrow$ | $2^{5}$        |
// |               | $\vdots$        | $\vdots$       |
// |               | $k\rightarrow$  | $2^{k}$        |
//
// Como se puede observar, el tiempo de ejecución de las sentencias es:
//
// $1+2+4+8+16+32+64+\cdots +k$
//
// La sumatoria será:
//
// $$\sum_{n=1}^{k}{2^{n-1}}= 2^{k}-1$$
//
// Como $i < n$, para que se detenga debera ser $i \geqslant n$.
//
// Entonces:
//
// $$k \geqslant n$$
//
// Reemplazando $k$:
//
// $$2^{k}-1 \geqslant n$$
//
// Tenemos una aproximación mediante las propiedades asintoticas:
// $$2^{k} \approx n$$
//
// Aplicando logaritmo en base 2:
//
// $$\log_{2}2^{k} \approx \log_{2}n$$
//
// $$k(\log_{2}2) \approx \log_{2}n$$
//
// Entonces tenemos que:
//
// $$k \approx \log_{2}n$$
//
// Por lo tanto la complejidad es $O(\log_{2}{n})$ es logarítmica
//
// ###Comprobando:
//
// Cuando $n=10$, entonces el $\log_{2}10=\left \lceil 3.3219 \right \rceil = 4$ iteraciones

// %% [markdown]
// ## Código implementando en Java:

// %%
/*
  Imprime las potencias de dos
*/
public void powerOfTwo(int n){
    // Dado un número imprime los numeros
    // de potencia 2 de los menores al número dado
    int count = 0;
    for (int i = 1; i < n; i=i*2){
        System.out.println("2^"+count+" = "+i);
        count++;
    }
}

// %%
powerOfTwo(10)
// Out:
// 2^0 = 1
// 2^1 = 2
// 2^2 = 4
// 2^3 = 8
