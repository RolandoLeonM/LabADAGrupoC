# %% [markdown]
# # Ejercicio 04. Retroceso
#
# Está enviando un mensaje a un amigo con un teclado especial.
# El teclado solo acepta letras minúsculas.
# Cuando se presiona el botón #, la última letra se elimina del mensaje. Dadas algunas pulsaciones de teclas: muestra el mensaje resultante.
#
# **Entrada: abc#de##f#ghi#jklmn#op#**
#
# **Salida: abghjklmo**

# %%
from collections import deque

def backSpace(S):
# Dada una cadena de caracteres la función muestra una
# cadena, resultado del #, que elimina el caracter
# que se encuentra a su izquierda.

    #agrega espacios entre caracteres para separarlos
    S1=" ".join(S)
    # crea colas vacias
    s = deque()
    cola = deque()
    # separa cada caracter como elemento de la cola
    s = S1.split()

    for i in s:
        if i != '#':
            cola.append(i)
        else:
            cola.pop()
            continue
    print(cola)

# %%
s = 'abc#de##f#ghi#jklmn#op#'
backSpace(s)
# Out:
# deque(['a', 'b', 'g', 'h', 'j', 'k', 'l', 'm', 'o'])
